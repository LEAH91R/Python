# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

# %%
random_int_array = np.random.randint(1, 50, size=(1, 10))
random_int_array
# Out:
# array([[36, 44, 35, 37, 37, 37, 40, 42, 15, 38]], dtype=int32)

# %%
np.mean(random_int_array)
# Out:
# np.float64(36.1)

# %%
np.mean(random_int_array)
# Out:
# np.float64(36.1)

# %%
two_dim = np.array([[1, 2, 3], [4, 5, 6], [5, 6, 7]])

# %%
two_dim.shape
# Out:
# (3, 3)

# %%
tow= np.array([[[12,15,60],[45,75,89]],[[12,15,45],[45,78,95]]])

# %%
tow.shape
# Out:
# (2, 2, 3)

# %%
total_sum = np.sum(tow)

# %%
print(f"הסכום הכולל: {total_sum}")
# Out:
# הסכום הכולל: 586

# %%
random_int = np.random.randint(1, 100, size=(1, 20))
random_int
# Out:
# array([[18, 54, 63, 56, 14, 46, 59, 84, 68,  7, 32, 23, 23, 34, 63, 47,
#         18, 44, 49, 21]], dtype=int32)

# %%
condition = random_int > 50
filtered_arr = random_int[condition]
filtered_arr
# Out:
# array([54, 63, 56, 59, 84, 68, 63], dtype=int32)

# %%
arr = np.arange(1, 11)

# %%
np.random.shuffle(arr)

# %%
selected_elements = arr[:4]
