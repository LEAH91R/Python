# %%
pip install numpy
# Out:
# Collecting numpy
#   Downloading numpy-2.4.4-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# Downloading numpy-2.4.4-cp313-cp313-win_amd64.whl (12.3 MB)
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.3 MB 6.6 MB/s eta 0:00:02
#    -------- ------------------------------- 2.6/12.3 MB 9.1 MB/s eta 0:00:02
#    --------------- ------------------------ 4.7/12.3 MB 9.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.3/12.3 MB 10.4 MB/s eta 0:00:01
#    -------------------------------- ------- 10.0/12.3 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------  12.1/12.3 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 10.4 MB/s  0:00:01
# Installing collected packages: numpy
# Successfully installed numpy-2.4.4
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

# %%
random_int_array = np.random.randint(1, 50, size=(1, 10))
random_int_array
# Out:
# array([[19, 49, 46, 37,  2, 19, 47, 28, 44, 25]], dtype=int32)

# %%
random_int_array.size
# Out:
# 10

# %%
random_int_array.shape
# Out:
# (1, 10)

# %%
random_int_array.dtype
# Out:
# dtype('int32')

# %%
random_int_array = np.random.randint(1, 100, size=(2, 5))
random_int_array
# Out:
# array([[22, 17, 15, 59, 96],
#        [81, 22, 36, 50, 72]], dtype=int32)

# %%
random_int_array.shape
# Out:
# (2, 5)
